# %%
import pandas as pd
import numpy as np


archivo = 'Quiz Cálculo 1- Gobierno 22 de Octubre(1-18).csv'
df = pd.read_csv(archivo)
def suma_digitos(num):
    return sum(int(d) for d in str(num) if d.isdigit())


df["n"] = df["Número de documento"].apply(suma_digitos)


def C(n, x):
    return n*(x**2) + 2*x + 23


valor_correcto_p1 = ((C(df["n"], 105) - C(df["n"], 100)) / 5).round(2)
df["CP1"] = (df.iloc[:,1] == valor_correcto_p1).astype(int) * 4 + 1


valor_correcto_p2 = (C(df["n"], 101) - C(df["n"], 100)).round(2)
df["CP2"] = (df.iloc[:,2] == valor_correcto_p2).astype(int) * 4 + 1


columna_p3 = df.iloc[:,3]
def limpiar_valor(valor):
    try:
        if isinstance(valor, str):
            valor = valor.replace(",",".")
            valor = valor.strip()
            if "," in valor and "." in valor:
                partes = valor.split(",")
                if len(partes) == 2:
                    valor = partes[0]+"."+partes[1]
        return float(valor)
    except (ValueError, AttributeError):
        return np.nan

valores_limpios_p3 = columna_p3.apply(limpiar_valor)
valor_correcto_p3 = (2*df["n"]*100 + 2).round(2)
df["CP3"] = np.where(valores_limpios_p3 == valor_correcto_p3, 5, 1)


df["Calificación Final"] = ((df["CP1"] + df["CP2"] + df["CP3"])/3).round(2)

df.to_csv(archivo, index=False)

print("Calificación final calculada y guardada en el archivo original.")
print(df[["Número de documento", "CP1", "CP2", "CP3", "Calificación Final"]].head())
print(df)
# Out:
# Calificación final calculada y guardada en el archivo original.
#    Número de documento  CP1  CP2  CP3  Calificación Final
# 0           1021674384    5    5    5                 5.0
# 1           1028481694    5    5    5                 5.0
# 2           1012976628    5    5    5                 5.0
# 3           1103500518    5    5    5                 5.0
# 4           1141316451    5    5    5                 5.0
#     Número de documento  \
# 0            1021674384
# 1            1028481694
# 2            1012976628
# 3            1103500518
# 4            1141316451
# 5            1127228530
# 6            1000794960
# 7            1019606644
# 8            1104224296
# 9            1094049572
# 10           1025062924
# 11           1028485597
# 12           1013037578
# 13           1113364165
# 14           1140914656
# 15           1011095164
# 16           1193231792
# 17           1077228324
#
#     Sea la función de costo C(x) = n*x^2 + 2*x + 23. \nHallar el costo promedio de producir  de 100 a 105 unidades (Poner dos decimales)  \
# 0                                            7382.000
# 1                                            8817.000
# 2                                            8612.000
# 3                                            4922.000
# 4                                            5537.000
# 5                                            6357.000
# 6                                            7382.000
# 7                                          389866.330
# 8                                            6356.600
# 9                                            8407.000
# 10                                              6.357
# 11                                          10047.000
# 12                                           7177.000
# 13                                           6357.000
# 14                                           7587.000
# 15                                           5740.000
# 16                                            175.000
# 17                                           7382.000
#
#     Sea la función de costo C(x) = n*x^2 + 2*x + 23. \nHallar el costo promedio de producir  de 100 a 101 unidades (Poner dos decimales)\n  \
# 0                                            7238.000
# 1                                            8645.000
# 2                                            8444.000
# 3                                            4826.000
# 4                                            5429.000
# 5                                            6233.000
# 6                                            7238.000
# 7                                            3739.230
# 8                                            6233.000
# 9                                            8243.000
# 10                                              6.233
# 11                                           9851.000
# 12                                           7037.000
# 13                                           6233.000
# 14                                           7439.000
# 15                                           5620.000
# 16                                            152.000
# 17                                           7238.000
#
#    Sea la función de costo C(x) = n*x^2 + 2*x + 23. \nUsar el costo marginal para aproximar el costo promedio entre x= 100 y x =101 (Poner dos decimales)  \
# 0                                             7202.00
# 1                                                8602
# 2                                                8402
# 3                                             4802.00
# 4                                                5402
# 5                                                6202
# 6                                                2.00
# 7                                             7402.00
# 8                                                  62
# 9                                                8202
# 10                                              6.202
# 11                                                  2
# 12                                               7002
# 13                                            6202.00
# 14                                                 76
# 15                                               5600
# 16                                                  1
# 17                                             366,82
#
#      n  CP1  CP2  CP3  Calificación Final
# 0   36    5    5    5                5.00
# 1   43    5    5    5                5.00
# 2   42    5    5    5                5.00
# 3   24    5    5    5                5.00
# 4   27    5    5    5                5.00
# 5   31    5    5    5                5.00
# 6   36    5    5    1                3.67
# 7   37    1    1    5                2.33
# 8   31    1    5    1                2.33
# 9   41    5    5    5                5.00
# 10  31    1    1    1                1.00
# 11  49    5    5    1                3.67
# 12  35    5    5    5                5.00
# 13  31    5    5    5                5.00
# 14  37    5    5    1                3.67
# 15  28    1    1    1                1.00
# 16  38    1    1    1                1.00
# 17  36    5    5    1                3.67
